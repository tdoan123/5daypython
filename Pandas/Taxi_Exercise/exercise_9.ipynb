# %%
# %pylab inline 
import pandas as pd
from pandas import Series, DataFrame
# Out:
# %pylab is deprecated, use %matplotlib inline and import the required libraries.
# Populating the interactive namespace from numpy and matplotlib

# %%
df = pd.read_csv(r'C:\Users\dqthi\OneDrive\Coding_Journey\CodeBreakThrough\Beginner_Python_Programming_All-in-One_Tutorial_Series\Pandas\Taxi_Exercise\flight-delays\flights.csv')
# Out:
# C:\Users\dqthi\AppData\Local\Temp\ipykernel_33484\1140797486.py:1: DtypeWarning: Columns (7,8) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(r'C:\Users\dqthi\OneDrive\Coding_Journey\CodeBreakThrough\Beginner_Python_Programming_All-in-One_Tutorial_Series\Pandas\Taxi_Exercise\flight-delays\flights.csv')

# %%
df
# Out:
#          YEAR  MONTH  DAY  DAY_OF_WEEK AIRLINE  FLIGHT_NUMBER TAIL_NUMBER  \
# 0        2015      1    1            4      AS             98      N407AS
# 1        2015      1    1            4      AA           2336      N3KUAA
# 2        2015      1    1            4      US            840      N171US
# 3        2015      1    1            4      AA            258      N3HYAA
# 4        2015      1    1            4      AS            135      N527AS
# ...       ...    ...  ...          ...     ...            ...         ...
# 5819074  2015     12   31            4      B6            688      N657JB
# 5819075  2015     12   31            4      B6            745      N828JB
# 5819076  2015     12   31            4      B6           1503      N913JB
# 5819077  2015     12   31            4      B6            333      N527JB
# 5819078  2015     12   31            4      B6            839      N534JB
#
#         ORIGIN_AIRPORT DESTINATION_AIRPORT  SCHEDULED_DEPARTURE  ...  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5819079 entries, 0 to 5819078
# Data columns (total 31 columns):
#  #   Column               Dtype
# ---  ------               -----
#  0   YEAR                 int64
#  1   MONTH                int64
#  2   DAY                  int64
#  3   DAY_OF_WEEK          int64
#  4   AIRLINE              object
#  5   FLIGHT_NUMBER        int64
#  6   TAIL_NUMBER          object
#  7   ORIGIN_AIRPORT       object
#  8   DESTINATION_AIRPORT  object
#  9   SCHEDULED_DEPARTURE  int64
#  10  DEPARTURE_TIME       float64
#  11  DEPARTURE_DELAY      float64
#  12  TAXI_OUT             float64
#  13  WHEELS_OFF           float64
#  14  SCHEDULED_TIME       float64
#  15  ELAPSED_TIME         float64
#  16  AIR_TIME             float64
#  17  DISTANCE             int64
#  18  WHEELS_ON            float64
#  19  TAXI_IN              float64
#  20  SCHEDULED_ARRIVAL    int64
#  21  ARRIVAL_TIME         float64
#  22  ARRIVAL_DELAY        float64
# ...

# %%
df.head()
# Out:
#    YEAR  MONTH  DAY  DAY_OF_WEEK AIRLINE  FLIGHT_NUMBER TAIL_NUMBER  \
# 0  2015      1    1            4      AS             98      N407AS
# 1  2015      1    1            4      AA           2336      N3KUAA
# 2  2015      1    1            4      US            840      N171US
# 3  2015      1    1            4      AA            258      N3HYAA
# 4  2015      1    1            4      AS            135      N527AS
#
#   ORIGIN_AIRPORT DESTINATION_AIRPORT  SCHEDULED_DEPARTURE  ...  ARRIVAL_TIME  \
# 0            ANC                 SEA                    5  ...         408.0
# 1            LAX                 PBI                   10  ...         741.0
# 2            SFO                 CLT                   20  ...         811.0
# 3            LAX                 MIA                   20  ...         756.0
# 4            SEA                 ANC                   25  ...         259.0
#
#    ARRIVAL_DELAY  DIVERTED  CANCELLED  CANCELLATION_REASON  AIR_SYSTEM_DELAY  \
# ...

# %%
df.describe()
# Out:
#             YEAR         MONTH           DAY   DAY_OF_WEEK  FLIGHT_NUMBER  \
# count  5819079.0  5.819079e+06  5.819079e+06  5.819079e+06   5.819079e+06
# mean      2015.0  6.524085e+00  1.570459e+01  3.926941e+00   2.173093e+03
# std          0.0  3.405137e+00  8.783425e+00  1.988845e+00   1.757064e+03
# min       2015.0  1.000000e+00  1.000000e+00  1.000000e+00   1.000000e+00
# 25%       2015.0  4.000000e+00  8.000000e+00  2.000000e+00   7.300000e+02
# 50%       2015.0  7.000000e+00  1.600000e+01  4.000000e+00   1.690000e+03
# 75%       2015.0  9.000000e+00  2.300000e+01  6.000000e+00   3.230000e+03
# max       2015.0  1.200000e+01  3.100000e+01  7.000000e+00   9.855000e+03
#
#        SCHEDULED_DEPARTURE  DEPARTURE_TIME  DEPARTURE_DELAY      TAXI_OUT  \
# count         5.819079e+06    5.732926e+06     5.732926e+06  5.730032e+06
# mean          1.329602e+03    1.335204e+03     9.370158e+00  1.607166e+01
# std           4.837518e+02    4.964233e+02     3.708094e+01  8.895574e+00
# ...

# %%
# how many flights are represented? 
# there are 5,819,079 flights information in the dataset. not quite sure if there is any duplicates and the time window of these files

# %%
# Which airline are represented? the top 3 airlines had the most flights in this database?

# %%
airline_df = df['AIRLINE']

# %%
airline_df.value_counts().iloc[0:3]
# Out:
# AIRLINE
# WN    1261855
# DL     875881
# AA     725984
# Name: count, dtype: int64

# %%
# what was the average delay time for flights in this database?

# %%
delay_df = df[['DEPARTURE_DELAY', 
               'AIRLINE',
               'ARRIVAL_DELAY']]

# %%
delay_df
# Out:
#          DEPARTURE_DELAY AIRLINE  ARRIVAL_DELAY
# 0                  -11.0      AS          -22.0
# 1                   -8.0      AA           -9.0
# 2                   -2.0      US            5.0
# 3                   -5.0      AA           -9.0
# 4                   -1.0      AS          -21.0
# ...                  ...     ...            ...
# 5819074             -4.0      B6          -26.0
# 5819075             -4.0      B6          -16.0
# 5819076             -9.0      B6           -8.0
# 5819077             -6.0      B6          -10.0
# 5819078             15.0      B6            2.0
#
# [5819079 rows x 3 columns]

# %%
delay_df['DEPARTURE_DELAY'].max()
# Out:
# 1988.0

# %%
delay_df['DEPARTURE_DELAY'].min()
# Out:
# -82.0

# %%
delay_df['DEPARTURE_DELAY'].mean()
# Out:
# 9.370158275198389

# %%
delay_df['DEPARTURE_DELAY'].describe()
# Out:
# count    5.732926e+06
# mean     9.370158e+00
# std      3.708094e+01
# min     -8.200000e+01
# 25%     -5.000000e+00
# 50%     -2.000000e+00
# 75%      7.000000e+00
# max      1.988000e+03
# Name: DEPARTURE_DELAY, dtype: float64

# %%
delay_df['AIRLINE'][delay_df['DEPARTURE_DELAY'].max()]
# Out:
# 'OO'

# %%
delay_df['ARRIVAL_DELAY'].max()
# Out:
# 1971.0

# %%
delay_df['ARRIVAL_DELAY'].mean()
# Out:
# 4.407057357987598

# %%
delay_df['ARRIVAL_DELAY'].min()
# Out:
# -87.0

# %%
delay_df['ARRIVAL_DELAY'].describe()
# Out:
# count    5.714008e+06
# mean     4.407057e+00
# std      3.927130e+01
# min     -8.700000e+01
# 25%     -1.300000e+01
# 50%     -5.000000e+00
# 75%      8.000000e+00
# max      1.971000e+03
# Name: ARRIVAL_DELAY, dtype: float64

# %%
delay_df.boxplot('ARRIVAL_DELAY')
# Out:
# <Axes: >

# %%
delay_df['AIRLINE'][delay_df['ARRIVAL_DELAY'].max()]
# Out:
# 'AA'

# %%
delay_df[delay_df['ARRIVAL_DELAY'] == delay_df['ARRIVAL_DELAY'].max()]
# Out:
#         DEPARTURE_DELAY AIRLINE  ARRIVAL_DELAY
# 337720           1988.0      AA         1971.0

# %%
delay_df
# Out:
#          DEPARTURE_DELAY AIRLINE  ARRIVAL_DELAY
# 0                  -11.0      AS          -22.0
# 1                   -8.0      AA           -9.0
# 2                   -2.0      US            5.0
# 3                   -5.0      AA           -9.0
# 4                   -1.0      AS          -21.0
# ...                  ...     ...            ...
# 5819074             -4.0      B6          -26.0
# 5819075             -4.0      B6          -16.0
# 5819076             -9.0      B6           -8.0
# 5819077             -6.0      B6          -10.0
# 5819078             15.0      B6            2.0
#
# [5819079 rows x 3 columns]

# %%
delay_df[delay_df['ARRIVAL_DELAY'] == delay_df['ARRIVAL_DELAY'].max()]
# Out:
#         DEPARTURE_DELAY AIRLINE  ARRIVAL_DELAY
# 337720           1988.0      AA         1971.0
