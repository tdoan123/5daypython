# %%
# %pylab inline 
import pandas as pd
from pandas import Series, DataFrame
# Out:
# %pylab is deprecated, use %matplotlib inline and import the required libraries.
# Populating the interactive namespace from numpy and matplotlib

# %%
# how to open the file to review 
filename = 'taxi.csv'

# %%
# !head taxi.csv
# Out:
# 'head' is not recognized as an internal or external command,
# operable program or batch file.

# %%
df = pd.read_csv('taxi.csv')

# %%
df
# Out:
#       VendorID tpep_pickup_datetime tpep_dropoff_datetime  passenger_count  \
# 0            2  2015-06-02 11:19:29   2015-06-02 11:47:52                1
# 1            2  2015-06-02 11:19:30   2015-06-02 11:27:56                1
# 2            2  2015-06-02 11:19:31   2015-06-02 11:30:30                1
# 3            2  2015-06-02 11:19:31   2015-06-02 11:39:02                1
# 4            1  2015-06-02 11:19:32   2015-06-02 11:32:49                1
# ...        ...                  ...                   ...              ...
# 9994         1  2015-06-01 00:12:59   2015-06-01 00:24:18                1
# 9995         1  2015-06-01 00:12:59   2015-06-01 00:28:16                1
# 9996         2  2015-06-01 00:13:00   2015-06-01 00:37:25                1
# 9997         2  2015-06-01 00:13:02   2015-06-01 00:19:10                6
# 9998         1  2015-06-01 00:13:04   2015-06-01 00:36:33                1
#
# ...

# %%
df.shape
# Out:
# (9999, 19)

# %%
df.info
# Out:
# <bound method DataFrame.info of       VendorID tpep_pickup_datetime tpep_dropoff_datetime  passenger_count  \
# 0            2  2015-06-02 11:19:29   2015-06-02 11:47:52                1
# 1            2  2015-06-02 11:19:30   2015-06-02 11:27:56                1
# 2            2  2015-06-02 11:19:31   2015-06-02 11:30:30                1
# 3            2  2015-06-02 11:19:31   2015-06-02 11:39:02                1
# 4            1  2015-06-02 11:19:32   2015-06-02 11:32:49                1
# ...        ...                  ...                   ...              ...
# 9994         1  2015-06-01 00:12:59   2015-06-01 00:24:18                1
# 9995         1  2015-06-01 00:12:59   2015-06-01 00:28:16                1
# 9996         2  2015-06-01 00:13:00   2015-06-01 00:37:25                1
# 9997         2  2015-06-01 00:13:02   2015-06-01 00:19:10                6
# 9998         1  2015-06-01 00:13:04   2015-06-01 00:36:33                1
#
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9999 entries, 0 to 9998
# Data columns (total 19 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   VendorID               9999 non-null   int64
#  1   tpep_pickup_datetime   9999 non-null   object
#  2   tpep_dropoff_datetime  9999 non-null   object
#  3   passenger_count        9999 non-null   int64
#  4   trip_distance          9999 non-null   float64
#  5   pickup_longitude       9999 non-null   float64
#  6   pickup_latitude        9999 non-null   float64
#  7   RateCodeID             9999 non-null   int64
#  8   store_and_fwd_flag     9999 non-null   object
#  9   dropoff_longitude      9999 non-null   float64
#  10  dropoff_latitude       9999 non-null   float64
#  11  payment_type           9999 non-null   int64
#  12  fare_amount            9999 non-null   float64
#  13  extra                  9999 non-null   float64
# ...

# %%
df1 = df[['passenger_count', 'trip_distance', 'total_amount']]

# %%
df1
# Out:
#       passenger_count  trip_distance  total_amount
# 0                   1           1.63         17.80
# 1                   1           0.46          8.30
# 2                   1           0.87         11.00
# 3                   1           2.13         17.16
# 4                   1           1.40         10.30
# ...               ...            ...           ...
# 9994                1           2.70         12.30
# 9995                1           4.50         20.30
# 9996                1           5.59         22.30
# 9997                6           1.54          7.80
# 9998                1           5.80         26.75
#
# [9999 rows x 3 columns]

# %%
# the above approach was to load the df with all of the columns, then I review the list of the column names, then assigned the columns that I want to use into the new data frame

# %%
help(pd.read_csv)
# Out:
# Help on function read_csv in module pandas.io.parsers.readers:
#
# ...

# %%
df2 = pd.read_csv('taxi.csv', usecols= ('passenger_count', 'trip_distance', 'total_amount'))
df2
# Out:
#       passenger_count  trip_distance  total_amount
# 0                   1           1.63         17.80
# 1                   1           0.46          8.30
# 2                   1           0.87         11.00
# 3                   1           2.13         17.16
# 4                   1           1.40         10.30
# ...               ...            ...           ...
# 9994                1           2.70         12.30
# 9995                1           4.50         20.30
# 9996                1           5.59         22.30
# 9997                6           1.54          7.80
# 9998                1           5.80         26.75
#
# [9999 rows x 3 columns]

# %%
# this method is calling the columns directly into the dataframe "df2"

# %%
df2.dtypes
# Out:
# passenger_count      int64
# trip_distance      float64
# total_amount       float64
# dtype: object

# %%
# (2) what was the average and standard deviation for trip distance and total amount

# %%
df2['trip_distance'].describe()
# Out:
# count    9999.000000
# mean        3.158511
# std         4.037516
# min         0.000000
# 25%         1.000000
# 50%         1.700000
# 75%         3.300000
# max        64.600000
# Name: trip_distance, dtype: float64

# %%
df2.value_counts(['trip_distance'])
# Out:
# trip_distance
# 1.10             249
# 0.90             241
# 1.00             238
# 0.70             230
# 0.80             228
#                 ...
# 9.34               1
# 9.32               1
# 9.31               1
# 9.28               1
# 64.60              1
# Name: count, Length: 1219, dtype: int64

# %%
trip_more_than_4 = df2[df2['trip_distance'].values > 4]
trip_more_than_4
# Out:
#       passenger_count  trip_distance  total_amount
# 7                   4          11.90         73.84
# 39                  2           5.28         24.96
# 43                  2           5.30         33.35
# 56                  1           4.71         22.88
# 60                  1           9.30         34.84
# ...               ...            ...           ...
# 9992                1           6.37         23.30
# 9993                1           4.10         18.30
# 9995                1           4.50         20.30
# 9996                1           5.59         22.30
# 9998                1           5.80         26.75
#
# [2068 rows x 3 columns]

# %%
trip_less_than_4  = df2[df2['trip_distance'].values < 4]
trip_less_than_4
# Out:
#       passenger_count  trip_distance  total_amount
# 0                   1           1.63         17.80
# 1                   1           0.46          8.30
# 2                   1           0.87         11.00
# 3                   1           2.13         17.16
# 4                   1           1.40         10.30
# ...               ...            ...           ...
# 9988                1           0.90          8.50
# 9989                6           1.34          8.76
# 9991                1           1.48          9.30
# 9994                1           2.70         12.30
# 9997                6           1.54          7.80
#
# [7911 rows x 3 columns]

# %%
trip_less_than_4.boxplot('trip_distance')
# Out:
# <Axes: >

# %%
trip_less_than_4['trip_distance'].describe()
# Out:
# count    7911.000000
# mean        1.533566
# std         0.869131
# min         0.000000
# 25%         0.890000
# 50%         1.340000
# 75%         2.050000
# max         3.990000
# Name: trip_distance, dtype: float64

# %%
df2.hist(['trip_distance'],bins= 20)
# Out:
# array([[<Axes: title={'center': 'trip_distance'}>]], dtype=object)

# %%
help(df2.hist)
# Out:
# Help on method hist_frame in module pandas.plotting._core:
#
# hist_frame(column: 'IndexLabel | None' = None, by=None, grid: 'bool' = True, xlabelsize: 'int | None' = None, xrot: 'float | None' = None, ylabelsize: 'int | None' = None, yrot: 'float | None' = None, ax=None, sharex: 'bool' = False, sharey: 'bool' = False, figsize: 'tuple[int, int] | None' = None, layout: 'tuple[int, int] | None' = None, bins: 'int | Sequence[int]' = 10, backend: 'str | None' = None, legend: 'bool' = False, **kwargs) method of pandas.core.frame.DataFrame instance
#     Make a histogram of the DataFrame's columns.
#
#     A `histogram`_ is a representation of the distribution of data.
#     This function calls :meth:`matplotlib.pyplot.hist`, on each series in
#     the DataFrame, resulting in one histogram per column.
#
#     .. _histogram: https://en.wikipedia.org/wiki/Histogram
#
#     Parameters
#     ----------
#     data : DataFrame
#         The pandas object holding the data.
# ...

# %%
df2.boxplot(['trip_distance'])
# Out:
# <Axes: >

# %%
df2.boxplot(['total_amount'])
# Out:
# <Axes: >

# %%
df2['total_amount'].describe()
# Out:
# count    9999.000000
# mean       17.552472
# std        15.137990
# min        -7.800000
# 25%         8.800000
# 50%        12.800000
# 75%        19.800000
# max       252.350000
# Name: total_amount, dtype: float64

# %%
df2[['total_amount', 'trip_distance']].describe()
# Out:
#        total_amount  trip_distance
# count   9999.000000    9999.000000
# mean      17.552472       3.158511
# std       15.137990       4.037516
# min       -7.800000       0.000000
# 25%        8.800000       1.000000
# 50%       12.800000       1.700000
# 75%       19.800000       3.300000
# max      252.350000      64.600000

# %%
# (3)  what were the most and least common number of passenger in taxi rides? 
# how often did each of these numbers take place 

df2.hist(['passenger_count'], bins = 30)
# Out:
# array([[<Axes: title={'center': 'passenger_count'}>]], dtype=object)

# %%
df2.value_counts(['passenger_count'])
# Out:
# passenger_count
# 1                  7207
# 2                  1313
# 5                   520
# 3                   406
# 6                   369
# 4                   182
# 0                     2
# Name: count, dtype: int64

# %%
df2['passenger_count'].value_counts(normalize = True).sort_values(ascending= False) * 100
# Out:
# passenger_count
# 1    72.077208
# 2    13.131313
# 5     5.200520
# 3     4.060406
# 6     3.690369
# 4     1.820182
# 0     0.020002
# Name: proportion, dtype: float64

# %%
# how many trips has 0 passenger? 
# - In how many ride did the passeneger *receive* money (total amount <= 0)
# - In how many rides did the taxi travel <0 0 miles?  

# for each of these, what was the average fare and distance for those ride?

# %%
df2[df2['passenger_count'] == 0]
# Out:
#       passenger_count  trip_distance  total_amount
# 5097                0            1.3         14.75
# 8313                0            7.9         36.39

# %%
df2['average_amount_distance'] = df2['total_amount'] / df2['trip_distance']

# %%
df2
# Out:
#       passenger_count  trip_distance  total_amount  average_amount_distance
# 0                   1           1.63         17.80                10.920245
# 1                   1           0.46          8.30                18.043478
# 2                   1           0.87         11.00                12.643678
# 3                   1           2.13         17.16                 8.056338
# 4                   1           1.40         10.30                 7.357143
# ...               ...            ...           ...                      ...
# 9994                1           2.70         12.30                 4.555556
# 9995                1           4.50         20.30                 4.511111
# 9996                1           5.59         22.30                 3.989267
# 9997                6           1.54          7.80                 5.064935
# 9998                1           5.80         26.75                 4.612069
#
# [9999 rows x 4 columns]

# %%
df2[df2['passenger_count'] == 0].mean()
# Out:
# passenger_count             0.000000
# trip_distance               4.600000
# total_amount               25.570000
# average_amount_distance     7.976241
# dtype: float64

# %%
# on average, how much % was tip as part of the total fare? 
# was this percentage higher for more than 1 passenger?

# %%
df4 = pd.read_csv('taxi.csv', usecols= ('passenger_count', 'trip_distance', 'total_amount', 'tip_amount' ))
df4
# Out:
#       passenger_count  trip_distance  tip_amount  total_amount
# 0                   1           1.63        0.00         17.80
# 1                   1           0.46        1.00          8.30
# 2                   1           0.87        2.20         11.00
# 3                   1           2.13        2.86         17.16
# 4                   1           1.40        0.00         10.30
# ...               ...            ...         ...           ...
# 9994                1           2.70        0.00         12.30
# 9995                1           4.50        3.00         20.30
# 9996                1           5.59        0.00         22.30
# 9997                6           1.54        0.00          7.80
# 9998                1           5.80        4.45         26.75
#
# [9999 rows x 4 columns]

# %%
df4['tip_per_passenger'] = df4['tip_amount'] / df4['passenger_count']
df4
# Out:
#       passenger_count  trip_distance  tip_amount  total_amount  tip_vs_total  \
# 0                   1           1.63        0.00         17.80      0.000000
# 1                   1           0.46        1.00          8.30      0.120482
# 2                   1           0.87        2.20         11.00      0.200000
# 3                   1           2.13        2.86         17.16      0.166667
# 4                   1           1.40        0.00         10.30      0.000000
# ...               ...            ...         ...           ...           ...
# 9994                1           2.70        0.00         12.30      0.000000
# 9995                1           4.50        3.00         20.30      0.147783
# 9996                1           5.59        0.00         22.30      0.000000
# 9997                6           1.54        0.00          7.80      0.000000
# 9998                1           5.80        4.45         26.75      0.166355
#
#       tip_per_passenger
# ...

# %%
df4['tip_vs_total'] = df4['tip_amount'] / df4['total_amount']
df4
# Out:
#       passenger_count  trip_distance  tip_amount  total_amount  tip_vs_total
# 0                   1           1.63        0.00         17.80      0.000000
# 1                   1           0.46        1.00          8.30      0.120482
# 2                   1           0.87        2.20         11.00      0.200000
# 3                   1           2.13        2.86         17.16      0.166667
# 4                   1           1.40        0.00         10.30      0.000000
# ...               ...            ...         ...           ...           ...
# 9994                1           2.70        0.00         12.30      0.000000
# 9995                1           4.50        3.00         20.30      0.147783
# 9996                1           5.59        0.00         22.30      0.000000
# 9997                6           1.54        0.00          7.80      0.000000
# 9998                1           5.80        4.45         26.75      0.166355
#
# [9999 rows x 5 columns]

# %%
df4['tip_vs_total'].mean()
# Out:
# 0.09161173442485882

# %%
df4['tip_per_passenger'][df4['passenger_count'] == 1].value_counts()
# Out:
# tip_per_passenger
# 0.00     3003
# 1.00      463
# 2.00      260
# 1.50      121
# 3.00       87
#          ...
# 17.50       1
# 10.70       1
# 11.21       1
# 3.07        1
# 8.66        1
# Name: count, Length: 473, dtype: int64

# %%
df4['passenger_count'][df4['tip_per_passenger'] == 1].mean()
# Out:
# 1.1225296442687747

# %%
df4['tip_per_passenger'][df4['passenger_count'] == 1].mean()
# Out:
# 1.836291105869294

# %%
df4[['passenger_count','tip_per_passenger']][df4['passenger_count'] == 1]
# Out:
#       passenger_count  tip_per_passenger
# 0                   1               0.00
# 1                   1               1.00
# 2                   1               2.20
# 3                   1               2.86
# 4                   1               0.00
# ...               ...                ...
# 9993                1               0.00
# 9994                1               0.00
# 9995                1               3.00
# 9996                1               0.00
# 9998                1               4.45
#
# [7207 rows x 2 columns]

# %%
df4['tip_per_passenger'][df4['passenger_count'] == 2].mean()
# Out:
# 0.9158910891089109

# %%
df4['tip_per_passenger'][df4['passenger_count'] == 3].mean()
# Out:
# 0.539696223316913

# %%
df4['tip_per_passenger'][df4['passenger_count'] == 4].mean()
# Out:
# 0.4321978021978022

# %%
df4['tip_per_passenger'][df4['passenger_count'] == 5].mean()
# Out:
# 0.36569230769230776

# %%
df4['tip_per_passenger'][df4['passenger_count'] == 6].mean()
# Out:
# 0.2744805781391147

# %%
df4['tip_per_passenger'][df4['passenger_count'] == 7].mean()
# Out:
# nan
