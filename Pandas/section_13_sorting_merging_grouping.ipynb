# %%
import pandas as pd
from pandas import Series, DataFrame

# %%
filename = r'C:\Users\dqthi\OneDrive\Coding_Journey\CodeBreakThrough\Beginner_Python_Programming_All-in-One_Tutorial_Series\Pandas\New folder\oecd_tourist_spending.csv'

df = pd.read_csv(filename)

# %%
df
# Out:
#     LOCATION     INDICATOR  SUBJECT MEASURE FREQUENCY  TIME      Value  \
# 0        AUS  TOUR_REC_EXP  INT_REC     USD         A  2008  31159.800
# 1        AUS  TOUR_REC_EXP  INT_REC     USD         A  2009  29980.700
# 2        AUS  TOUR_REC_EXP  INT_REC     USD         A  2010  35165.500
# 3        AUS  TOUR_REC_EXP  INT_REC     USD         A  2011  38710.100
# 4        AUS  TOUR_REC_EXP  INT_REC     USD         A  2012  38003.700
# ..       ...           ...      ...     ...       ...   ...        ...
# 510      ZAF  TOUR_REC_EXP  INT_REC     USD         A  2013  10467.550
# 511      ZAF  TOUR_REC_EXP  INT_REC     USD         A  2014  10484.152
# 512      ZAF  TOUR_REC_EXP  INT_REC     USD         A  2015   9139.363
# 513      ZAF  TOUR_REC_EXP  INT_REC     USD         A  2016   8807.601
# 514      ZAF  TOUR_REC_EXP  INT_REC     USD         A  2017   9698.740
#
#      Flag Codes
# 0           NaN
# 1           NaN
# 2           NaN
# 3           NaN
# 4           NaN
# ...

# %%
df['LOCATION'].unique()
# Out:
# array(['AUS', 'AUT', 'BEL', 'CAN', 'CZE', 'DNK', 'FIN', 'FRA', 'DEU',
#        'GRC', 'HUN', 'ISL', 'IRL', 'ITA', 'JPN', 'KOR', 'LUX', 'MEX',
#        'NLD', 'NZL', 'NOR', 'POL', 'PRT', 'SVK', 'ESP', 'SWE', 'CHE',
#        'TUR', 'GBR', 'USA', 'BRA', 'BGR', 'CHL', 'COL', 'CRI', 'HRV',
#        'EGY', 'EST', 'IND', 'IDN', 'ISR', 'LVA', 'LTU', 'MKD', 'MLT',
#        'MAR', 'PER', 'PHL', 'ROU', 'RUS', 'SVN', 'ZAF'], dtype=object)

# %%
df['Value'].mean()
# Out:
# 18296.13230291262

# %%
df.groupby(['TIME'])

# %%
df.groupby('TIME')['Value'].mean()
# Out:
# TIME
# 2008    17084.970720
# 2009    15118.594118
# 2010    15821.051442
# 2011    17652.056712
# 2012    17946.594058
# 2013    18934.598808
# 2014    20157.670058
# 2015    19414.856308
# 2016    19584.547596
# 2017    21252.396020
# Name: Value, dtype: float64

# %%
df.groupby('LOCATION')['Value'].mean().sort_values(ascending=False)
# Out:
# LOCATION
# USA    206854.800000
# FRA     64390.479300
# ESP     63847.169100
# DEU     52642.147700
# GBR     52372.260000
# ITA     44234.962700
# AUS     36730.620000
# TUR     30058.170000
# AUT     21991.710000
# JPN     20276.730000
# CAN     19847.280000
# NLD     19395.920000
# CHE     18964.560000
# IND     18647.808100
# KOR     17695.470000
# GRC     16385.729600
# MEX     15840.180000
# RUS     15676.011111
# PRT     15650.809300
# BEL     13582.010800
# SWE     12994.145400
# POL     11876.841700
# IRL     10118.423100
# IDN     10092.091800
# ZAF      9867.683600
# HRV      9684.225000
# DNK      9125.413400
# EGY      8969.110000
# NZL      8888.340000
# MAR      8306.164900
# CZE      7871.764500
# HUN      7056.408300
# BRA      6253.455100
# ISR      6162.269900
# LUX      5078.503800
# NOR      5075.088889
# PHL      5003.403400
# COL      4375.010000
# FIN      4241.829900
# BGR      4113.030000
# PER      3237.257400
# CHL      3121.800000
# CRI      2938.600000
# ...

# %%
df.groupby(['LOCATION','TIME'])['Value'].mean()
# Out:
# LOCATION  TIME
# AUS       2008    31159.800
#           2009    29980.700
#           2010    35165.500
#           2011    38710.100
#           2012    38003.700
#                     ...
# ZAF       2013    10467.550
#           2014    10484.152
#           2015     9139.363
#           2016     8807.601
#           2017     9698.740
# Name: Value, Length: 515, dtype: float64

# %%
df.head()
# Out:
#   LOCATION     INDICATOR  SUBJECT MEASURE FREQUENCY  TIME    Value  Flag Codes
# 0      AUS  TOUR_REC_EXP  INT_REC     USD         A  2008  31159.8         NaN
# 1      AUS  TOUR_REC_EXP  INT_REC     USD         A  2009  29980.7         NaN
# 2      AUS  TOUR_REC_EXP  INT_REC     USD         A  2010  35165.5         NaN
# 3      AUS  TOUR_REC_EXP  INT_REC     USD         A  2011  38710.1         NaN
# 4      AUS  TOUR_REC_EXP  INT_REC     USD         A  2012  38003.7         NaN

# %%
# create a table so that the country is the index, and the column time is columns while the value is the value

# %%
df.pivot(index='LOCATION', columns='TIME', values='Value')
# Out:
# TIME            2008        2009        2010        2011        2012  \
# LOCATION
# AUS        31159.800   29980.700   35165.500   38710.100   38003.700
# AUT        24187.200   21356.000   20798.800   22500.700   21390.400
# BEL        13117.515   13008.393   12682.700   14062.600   13723.500
# BGR         4646.888    4113.432    3883.297    4235.300    4043.182
# BRA         6109.375    5634.802    5521.890    6369.690    6623.421
# CAN        18027.400   15435.100   18451.500   19954.900   20691.700
# CHE        17596.900   16667.300   17614.100   20658.400   19594.100
# CHL         2481.000    2379.900    2362.200    2722.300    3158.700
# COL         2935.900    3049.700    3440.200    3801.300    4363.600
# CRI         2811.900    2215.800    2426.400    2645.700    2772.700
# CZE         8801.611    7874.834    8065.400    8929.000    8174.100
# DEU        53187.828   47203.349   49236.800   53333.800   51727.200
# ...
